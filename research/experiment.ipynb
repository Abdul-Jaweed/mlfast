# %%
import pandas as pd

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   63    1   1       145   233    1        2      150      0      2.3      3  \
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   1       145   233    1        2      150      0      2.3  \
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope      ca  thal
# 0        3       0     6
# 1        2       3     3
# 2        2       2     7
# 3        3       0     3
# 4        1       0     3
# ..     ...     ...   ...
# 298      2       0     7
# 299      2       2     7
# 300      2       1     7
# 301      2       1     3
# 302      1 -100000     3
#
# [303 rows x 13 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 298    1
# 299    1
# 300    1
# 301    1
# 302    0
# Name: num, Length: 303, dtype: int64

# %%
import mlfast

# %%
from mlfast import Classification

# %%
Classification(X,y,model='lr')
# Out:
# Accuracy Score :0.819672131147541,
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.74      0.88      0.81        26
#            1       0.90      0.77      0.83        35
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.83      0.82        61
# weighted avg       0.83      0.82      0.82        61
#
#
#  Model saved successfully in model\lr.pkl

# %%
df1 = pd.read_csv("ParisHousing.csv")
df1.head()
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode
# 0         75523              3        0        1      63      9373  \
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector
# 0              3              8  2005           0                  1  \
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
#
#    basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# 0      4313   9005     956               0             7  7559081.5
# 1      3653   2436     128               1             2  8085989.5
# 2      2937   8852     135               1             9  5574642.1
# 3       659   7141     359               0             3  3232561.2
# 4      8435   2429     292               1             4  7055052.0

# %%
X = df1.iloc[:,:-1]
y = df1.iloc[:,-1]

# %%
X
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode
# 0            75523              3        0        1      63      9373  \
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector
# 0                 3              8  2005           0                  1  \
# 1                 8              6  2015           1                  0
# 2                 6              8  2021           0                  0
# 3                10              4  2012           0                  1
# 4                 3              7  1990           1                  0
# ...             ...            ...   ...         ...                ...
# 9995              7              6  2009           0                  1
# 9996              9              4  1990           0                  1
# 9997             10             10  2005           1                  1
# 9998              1              3  2010           0                  1
# 9999              6             10  1994           1                  0
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom
# 0         4313   9005     956               0             7
# 1         3653   2436     128               1             2
# 2         2937   8852     135               1             9
# 3          659   7141     359               0             3
# 4         8435   2429     292               1             4
# ...        ...    ...     ...             ...           ...
# 9995      9311   1698     218               0             4
# 9996      9061   1742     230               0             0
# 9997      8304   7730     345               1             9
# 9998      2590   6174     339               1             4
# 9999      8485   2024     278               1             6
#
# [10000 rows x 16 columns]

# %%
y
# Out:
# 0       7559081.5
# 1       8085989.5
# 2       5574642.1
# 3       3232561.2
# 4       7055052.0
#           ...
# 9995     176425.9
# 9996    4448474.0
# 9997    8390030.5
# 9998    5905107.0
# 9999     146708.4
# Name: price, Length: 10000, dtype: float64

# %%
from mlfast import Regression

# %%
Regression(X, y, model='lr')
# Out:
#  Mean Absolute Error :1489.861712344069,
#
#  Mean Squared Error :3713559.532090714,
#
#  Root Mean Squared Error :1927.0598153899411,
#
#  R2 Score :0.9999995538620002
#
#  Model saved successfully in model\lr.pkl

# %%
df2 = pd.read_csv("diamonds_data.csv")
df2.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
X = df2.drop(columns='price')
y = df2.price

# %%
X
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
Regression(X, y, cat=True)
# Out:
#  Mean Absolute Error :735.9598135659993,
#
#  Mean Squared Error :1240728.3175655333,
#
#  Root Mean Squared Error :1113.879848801267,
#
#  R2 Score :0.9221707724305345
#
#  Model saved successfully in model\lr.pkl
